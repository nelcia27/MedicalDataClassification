# %%
import matplotlib.pyplot as plt

fig, (axs1, axs2) = plt.subplots(1, 2, figsize=(15, 6))
data = [23.2, 15.2, 22.9, 7.0, 23.5, 8.3]
label = ['age', 'pregnancy', 'attempts', 'endometrium', 'sperm', 'frozen_embryos', 'cleavage_stage']
label1 = ['age', 'pregnancy', 'attempts', 'endometrium', 'sperm', 'frozen_embryos']
axs1.pie(data, labels=label1, autopct='%1.1f%%', startangle=90)
axs1.set_title('DRSA, DOMLEM')
data = [26.2, 14.4, 11.8, 7.1, 21.2, 9.7, 9.6]
axs2.pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs2.set_title('DRSA, DOMApriori')
plt.savefig('mgr_res/drsa_2.jpg')
plt.show()

# %%
fig, (axs1, axs2) = plt.subplots(1, 2, figsize=(15, 6))
data = [23.2, 15.2, 22.9, 7.0, 23.5, 8.3]
axs1.pie(data, labels=label1, autopct='%1.1f%%', startangle=90)
axs1.set_title('VC-DRSA l=0.9, DOMLEM') 
data = [26.2, 14.4, 11.8, 7.1, 21.2, 9.7, 9.6]
axs2.pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs2.set_title('VC-DRSA l=0.9, DOMApriori')
plt.savefig('mgr_res/vc_drsa_2.jpg')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 12))
data = [22.6, 10.6, 0.1, 0.7, 6.3, 46.3, 13.4]
axs[0, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[0, 0].set_title('drzewo CART, brak ważenia klas, indeks Gini')
data = [41.3, 10.6, 12.8, 35.0, 10.3]
axs[0, 1].pie(data, labels=label2, autopct='%1.1f%%', startangle=90)
axs[0, 1].set_title('drzewo CART, brak ważenia klas, entropia')
data = [24.5, 2.4, 2.7, 1.5,  5.6, 38.3, 24.94]
axs[1, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[1, 0].set_title('drzewo CART, ważenie klas, indeks Gini')
data = [42.9, 9.8, 3.2, 29.5, 15.3]
label2 = ['age', 'pregnancy', 'attempts, endometrium i sperm', 'frozen_embryos', 'cleavage_stage']
axs[1, 1].pie(data, labels=label2, autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title('drzewo CART, ważenie klas, entropia')
plt.savefig('mgr_res/tree_2.jpg')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 18))
data = [23.3, 5.2, 8.0, 4.2, 8.2, 34.4, 16.7]
axs[0, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[0, 0].set_title('losowy las, brak ważenia klas, indeks Gini')
data = [28.8, 6.2, 6.0, 3.4, 8.8, 29.4, 17.4]
axs[0, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[0, 1].set_title('losowy las, brak ważenia klas, entropia')
data = [25.5, 2.7, 7.1, 3.7, 8.7, 33.3, 19.0]
axs[1, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[1, 0].set_title('losowy las, ważenie klas, indeks Gini')
data = [26.3, 6.9, 5.8, 3.0, 9.1, 29.4, 19.4]
axs[1, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title('losowy las, ważenie klas, entropia')
data = [23.6, 4.2, 7.6, 3.9, 8.5, 32.1, 20.0]
axs[2, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[2, 0].set_title('losowy las, subzbalansowanie klas, indeks Gini')
data = [25.1, 6.5, 4.9, 4.0, 9.6, 32.9, 17.1]
axs[2, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[2, 1].set_title('losowy las, subzbalansowanie klas, entropia')
plt.savefig('mgr_res/rf_2_2.jpg')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 18))
data = [25.1, 4.8, 7.2, 3.1, 8.8, 33.1, 18.0]
axs[0, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[0, 0].set_title('losowy las, brak ważenia klas, indeks Gini')
data = [25.0, 6.7, 6.5, 3.9, 9.4, 31.6, 16.9]
axs[0, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[0, 1].set_title('losowy las, brak ważenia klas, entropia')
data = [26.4, 5.1, 6.4, 2.7, 8.2, 31.2, 20.0]
axs[1, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[1, 0].set_title('losowy las, ważenie klas, indeks Gini')
data = [25.6, 5.4, 6.3, 3.3, 9.4, 31.7, 18.3]
axs[1, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title('losowy las, ważenie klas, entropia')
data = [22.9, 4.5, 8.1, 3.3, 7.5, 32.7, 21.0]
axs[2, 0].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[2, 0].set_title('losowy las, subzbalansowanie klas, indeks Gini')
data = [25.4, 5.4, 7.0, 4.0, 8.3, 30.0, 19.7]
axs[2, 1].pie(data, labels=label, autopct='%1.1f%%', startangle=90)
axs[2, 1].set_title('losowy las, subzbalansowanie klas, entropia')
plt.savefig('mgr_res/rf_3_2.jpg')
plt.show()
