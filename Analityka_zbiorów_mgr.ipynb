# %% [markdown]
# # Zbiór 1

# %%
import pandas as pd

dane = pd.read_csv("C:\\Users\\Kornelia\\Desktop\\mgr1.csv", sep = ",")

# %%
dane
# Out:
#     age   infertility   oocytes   woman_eval   sperm   morpho_quality  \
# 0    36             1         6            4       3               16
# 1    28             1         2            5       2               20
# 2    38             1         6            1       3               14
# 3    28             6         2            6       3                8
# 4    44             3         2            3       1               11
# 5    42             4         4            3       3               14
# 6    30             1         6            4       2                7
# 7    33             2         4            4       3               17
# 8    36             3         5            2       3                9
# 9    27             2         2            4       3               16
# 10   39             3         4            3       3                5
# 11   36             1         4            3       3               14
# ...

# %%
l = ["a"+str(i) for i in range(1,52)]

# %%
l = ["a"+str(i) for i in range(1,52)]
dane["Object"] = l
cols = dane.columns.tolist()
cols = cols[-1:] + cols[:-1]
dane = dane[cols]

# %%
dane
# Out:
#    Object  age   infertility   oocytes   woman_eval   sperm   morpho_quality  \
# 0      a1   36             1         6            4       3               16
# 1      a2   28             1         2            5       2               20
# 2      a3   38             1         6            1       3               14
# 3      a4   28             6         2            6       3                8
# 4      a5   44             3         2            3       1               11
# 5      a6   42             4         4            3       3               14
# 6      a7   30             1         6            4       2                7
# 7      a8   33             2         4            4       3               17
# 8      a9   36             3         5            2       3                9
# 9     a10   27             2         2            4       3               16
# 10    a11   39             3         4            3       3                5
# ...

# %%
print(dane.to_latex(longtable=True, index=False))
# Out:
# \begin{longtable}{lrrrrrrrr}
# \toprule
# Object &  age &   infertility &   oocytes &   woman\_eval &   sperm &   morpho\_quality &   develop\_quality &   class \\
# \midrule
# \endfirsthead
#
# \toprule
# Object &  age &   infertility &   oocytes &   woman\_eval &   sperm &   morpho\_quality &   develop\_quality &   class \\
# \midrule
# \endhead
# \midrule
# \multicolumn{9}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
#     a1 &   36 &             1 &         6 &            4 &       3 &               16 &                 3 &       2 \\
#     a2 &   28 &             1 &         2 &            5 &       2 &               20 &                 5 &       3 \\
#     a3 &   38 &             1 &         6 &            1 &       3 &               14 &                 4 &       3 \\
#     a4 &   28 &             6 &         2 &            6 &       3 &                8 &                 3 &       3 \\
# ...

# %%
dane.dtypes
# Out:
# age                 int64
#  infertility        int64
#  oocytes            int64
#  woman_eval         int64
#  sperm              int64
#  morpho_quality     int64
#  develop_quality    int64
#  class              int64
# dtype: object

# %%
cols = list(dane.columns)

# %%
dane.loc[dane[cols[-1]] == 1.0].shape
# Out:
# (1, 8)

# %%
dane.loc[dane[cols[-1]] == 2.0].shape
# Out:
# (9, 8)

# %%
dane.loc[dane[cols[-1]] == 3.0].shape
# Out:
# (40, 8)

# %%
dane.loc[dane[cols[-1]] == 4.0].shape
# Out:
# (1, 8)

# %%
import matplotlib.pyplot as plt
boxplot = dane.boxplot(column=cols[0:],figsize=(12,10))
plt.title("Wykres pudełkowy rozkładu wartości w poszczególnych kolumnach zbioru danych")
plt.savefig('box_plot_mgr.png', bbox_inches='tight')
plt.show()

# %%
freqs_tabs = []
for c in cols:
    freq_tab = pd.DataFrame(dane[c].value_counts())
    freq_tab = freq_tab.sort_values(by = c)
    freqs_tabs.append(freq_tab)

# %%
freqs_tabs[0]
# Out:
#     age
# 44    1
# 35    1
# 42    1
# 41    1
# 26    1
# 31    1
# 39    2
# 27    2
# 32    2
# 40    3
# 38    4
# 37    4
# 36    4
# 28    4
# 30    5
# 34    7
# 33    8

# %%
freqs_tabs[1]
# Out:
#      infertility
# 7              1
# 12             1
# 13             1
# 5              3
# 4              4
# 6              4
# 1              6
# 2             14
# 3             17

# %%
freqs_tabs[2]
# Out:
#     oocytes
# 2         5
# 6         5
# 1         6
# 5         9
# 4        10
# 3        16

# %%
freqs_tabs[3]
# Out:
#     woman_eval
# 1            1
# 6            2
# 5            5
# 2           11
# 4           13
# 3           19

# %%
freqs_tabs[4]
# Out:
#     sperm
# 1       2
# 2       2
# 3      47

# %%
freqs_tabs[5]
# Out:
#      morpho_quality
# 5                 1
# 7                 1
# 11                1
# 18                1
# 8                 2
# 9                 2
# 19                2
# 20                2
# 17                3
# 10                4
# 13                4
# 12                5
# 15                5
# 14                9
# 16                9

# %%
freqs_tabs[7]
# Out:
#     class
# 1       1
# 4       1
# 2       9
# 3      40

# %%
df = pd.DataFrame(dane.nunique())

# %%
mean = dane.mean(axis=0).round(2)

# %%
std = dane.std(axis=0).round(2)

# %%
median = dane.median(axis = 0).round(2)

# %%
df["Średnia"] = mean
df["Odchylenie standardowe"] = std
df["Mediana"] = median

# %%
df.rename(columns={0: "liczba unikatowych wartości"})
# Out:
#                   liczba unikatowych wartości  Średnia  \
# age                                        17    34.18
#  infertility                                9     3.37
#  oocytes                                    6     3.51
#  woman_eval                                 6     3.31
#  sperm                                      3     2.88
#  morpho_quality                            15    13.75
#  develop_quality                            5     3.76
#  class                                      4     2.80
#
#                   Odchylenie standardowe  Mediana
# age                                 4.24     34.0
#  infertility                        2.37      3.0
#  oocytes                            1.46      3.0
#  woman_eval                         1.10      3.0
#  sperm                              0.43      3.0
#  morpho_quality                     3.32     14.0
#  develop_quality                    1.27      4.0
#  class                              0.49      3.0

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &   0 &  Średnia &  Odchylenie standardowe &  Mediana \\
# \midrule
# age              &  17 &    34.18 &                    4.24 &     34.0 \\
#  infertility     &   9 &     3.37 &                    2.37 &      3.0 \\
#  oocytes         &   6 &     3.51 &                    1.46 &      3.0 \\
#  woman\_eval      &   6 &     3.31 &                    1.10 &      3.0 \\
#  sperm           &   3 &     2.88 &                    0.43 &      3.0 \\
#  morpho\_quality  &  15 &    13.75 &                    3.32 &     14.0 \\
#  develop\_quality &   5 &     3.76 &                    1.27 &      4.0 \\
#  class           &   4 &     2.80 &                    0.49 &      3.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Zbiór 2

# %%
import pandas as pd

dane = pd.read_csv("C:\\Users\\Kornelia\\Desktop\\mgr2.csv", sep = ",")

# %%
dane
# Out:
#     age  pregnancy  attempts  endometrium  sperm  frozen_embryos  \
# 0    23          0         3            1      1               4
# 1    39          0         1            2      1               1
# 2    42          0         3            1      1               2
# 3    37          1         1            1      2               2
# 4    34          1         1            1      2               2
# 5    32          0         1            2      1               8
# 6    27          0         4            2      1               5
# 7    34          1         1            1      1               6
# 8    31          0         1            1      1               4
# 9    36          0         1            2      1               2
# 10   22          0         1            1      1               2
# 11   31          1         1            1      2               3
# 12   33          1         3            1      2               5
# ...

# %%
l = ["a"+str(i) for i in range(1,26)]
dane["Object"] = l
cols = dane.columns.tolist()
cols = cols[-1:] + cols[:-1]
dane = dane[cols]

# %%
dane
# Out:
#    Object  age  pregnancy  attempts  endometrium  sperm  frozen_embryos  \
# 0      a1   23          0         3            1      1               4
# 1      a2   39          0         1            2      1               1
# 2      a3   42          0         3            1      1               2
# 3      a4   37          1         1            1      2               2
# 4      a5   34          1         1            1      2               2
# 5      a6   32          0         1            2      1               8
# 6      a7   27          0         4            2      1               5
# 7      a8   34          1         1            1      1               6
# 8      a9   31          0         1            1      1               4
# 9     a10   36          0         1            2      1               2
# 10    a11   22          0         1            1      1               2
# 11    a12   31          1         1            1      2               3
# ...

# %%
print(dane.to_latex(longtable=True))
# Out:
# \begin{longtable}{llrrrrrrrr}
# \toprule
# {} & Object &  age &  pregnancy &  attempts &  endometrium &  sperm &  frozen\_embryos &  cleavage\_stage &  class \\
# \midrule
# \endfirsthead
#
# \toprule
# {} & Object &  age &  pregnancy &  attempts &  endometrium &  sperm &  frozen\_embryos &  cleavage\_stage &  class \\
# \midrule
# \endhead
# \midrule
# \multicolumn{10}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
# 0  &     a1 &   23 &          0 &         3 &            1 &      1 &               4 &               5 &      1 \\
# 1  &     a2 &   39 &          0 &         1 &            2 &      1 &               1 &               5 &      2 \\
# 2  &     a3 &   42 &          0 &         3 &            1 &      1 &               2 &               8 &      1 \\
# 3  &     a4 &   37 &          1 &         1 &            1 &      2 &               2 &               5 &      2 \\
# ...

# %%
dane.dtypes
# Out:
# age               int64
# pregnancy         int64
# attempts          int64
# endometrium       int64
# sperm             int64
# frozen_embryos    int64
# cleavage_stage    int64
# class             int64
# dtype: object

# %%
cols = list(dane.columns)

# %%
dane.loc[dane[cols[-1]] == 1.0].shape
# Out:
# (15, 8)

# %%
dane.loc[dane[cols[-1]] == 2.0].shape
# Out:
# (10, 8)

# %%
import matplotlib.pyplot as plt
boxplot = dane.boxplot(column=cols[0:],figsize=(12,10))
plt.title("Wykres pudełkowy rozkładu wartości w poszczególnych kolumnach zbioru danych")
plt.savefig('box_plot_mgr2.png', bbox_inches='tight')
plt.show()

# %%
freqs_tabs = []
for c in cols:
    freq_tab = pd.DataFrame(dane[c].value_counts())
    freq_tab = freq_tab.sort_values(by = c)
    freqs_tabs.append(freq_tab)

# %%
freqs_tabs[0]
# Out:
#     age
# 33    1
# 41    1
# 22    1
# 23    1
# 24    1
# 27    1
# 29    1
# 36    2
# 37    2
# 39    2
# 40    2
# 42    2
# 31    2
# 32    3
# 34    3

# %%
freqs_tabs[1]
# Out:
#    pregnancy
# 1         12
# 0         13

# %%
freqs_tabs[2]
# Out:
#    attempts
# 4         2
# 3         3
# 1        20

# %%
freqs_tabs[3]
# Out:
#    endometrium
# 2           10
# 1           15

# %%
freqs_tabs[4]
# Out:
#    sperm
# 3      2
# 2      4
# 1     19

# %%
freqs_tabs[5]
# Out:
#     frozen_embryos
# 7                1
# 10               1
# 1                2
# 6                2
# 8                2
# 3                3
# 5                3
# 2                5
# 4                6

# %%
freqs_tabs[6]
# Out:
#    cleavage_stage
# 4               1
# 6               1
# 9               2
# 8               4
# 2               6
# 5              11

# %%
freqs_tabs[7]
# Out:
#    class
# 2     10
# 1     15

# %%
df = pd.DataFrame(dane.nunique())
mean = dane.mean(axis=0).round(2)
std = dane.std(axis=0).round(2)
median = dane.median(axis = 0).round(2)
df["Średnia"] = mean
df["Odchylenie standardowe"] = std
df["Mediana"] = median
df.rename(columns={0: "liczba unikatowych wartości"})
# Out:
#                 liczba unikatowych wartości  Średnia  Odchylenie standardowe  \
# age                                      15    33.88                    5.75
# pregnancy                                 2     0.48                    0.51
# attempts                                  3     1.48                    1.00
# endometrium                               2     1.40                    0.50
# sperm                                     3     1.32                    0.63
# frozen_embryos                            9     4.20                    2.31
# cleavage_stage                            6     5.08                    2.27
# class                                     2     1.40                    0.50
#
#                 Mediana
# age                34.0
# pregnancy           0.0
# attempts            1.0
# endometrium         1.0
# sperm               1.0
# frozen_embryos      4.0
# cleavage_stage      5.0
# class               1.0

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &   0 &  Średnia &  Odchylenie standardowe &  Mediana \\
# \midrule
# age            &  15 &    33.88 &                    5.75 &     34.0 \\
# pregnancy      &   2 &     0.48 &                    0.51 &      0.0 \\
# attempts       &   3 &     1.48 &                    1.00 &      1.0 \\
# endometrium    &   2 &     1.40 &                    0.50 &      1.0 \\
# sperm          &   3 &     1.32 &                    0.63 &      1.0 \\
# frozen\_embryos &   9 &     4.20 &                    2.31 &      4.0 \\
# cleavage\_stage &   6 &     5.08 &                    2.27 &      5.0 \\
# class          &   2 &     1.40 &                    0.50 &      1.0 \\
# \bottomrule
# \end{tabular}

# %%
a =[1,2]
b = [3]

# %%
a+b
# Out:
# [1, 2, 3]

# %%
set(a+b)
# Out:
# {1, 2, 3}

# %%
import itertools

# %%
c =list(itertools.combinations(set(a+b), 2))

# %%
print(c)
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
type(c[0])
# Out:
# tuple

# %%
from sklearn.datasets import load_wine

wine = load_wine()
X = wine.data
y = wine.target

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
l = ['a18', 'a47', 'a39', 'a13', 'a12', 'a45', 'a43', 'a8', 'a14', 'a46', 'a49', 'a25', 'a48', 'a22', 'a7', 'a38', 'a10', 'a2', 'a1']

# %%
l1 = [int(a[1:]) for a in l]
l1 = sorted(l1)

# %%
l2 = ["a"+str(i) for i in l1]

# %%
l2
# Out:
# ['a1',
#  'a2',
#  'a7',
#  'a8',
#  'a10',
#  'a12',
#  'a13',
#  'a14',
#  'a18',
#  'a22',
#  'a25',
#  'a38',
#  'a39',
#  'a43',
#  'a45',
#  'a46',
#  'a47',
#  'a48',
#  'a49']

# %%
a = [a1, a2, a4, a5, a6, a7, a8, a9, a10, a11, a12, a13, a14, a15, a16, a17, a18, a19, a20, a21, a22, a24, a25, a26, a27, a28, a29, a30, a31, a32, a33, a34, a35, a36, a37, a38, a39, a40, a41, a42, a43, a44, a45, a46, a47, a48, a49, a50, a51]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6c453e075330> in <module>
# ----> 1 a = [a1, a2, a4, a5, a6, a7, a8, a9, a10, a11, a12, a13, a14, a15, a16, a17, a18, a19, a20, a21, a22, a24, a25, a26, a27, a28, a29, a30, a31, a32, a33, a34, a35, a36, a37, a38, a39, a40, a41, a42, a43, a44, a45, a46, a47, a48, a49, a50, a51]
#
# NameError: name 'a1' is not defined
